# %%
from outlier_hub.datasets.odr.factory import ODRFactory
from data_stack.io.storage_connectors import FileStorageConnector
import os
import pathlib
import matplotlib.pyplot as plt
from data_stack.util.logger import logger

logger.debug(f"starting event")

# get root workind directory path
root_path = pathlib.Path.cwd().parents[3]

# complete path to manual added data
data_path = os.path.join(root_path, "src/outlier_hub/datasets/odr/data")

storage_connector = FileStorageConnector(root_path=data_path)

odr_factory = ODRFactory(storage_connector)

odr_iterator, _ = odr_factory.get_dataset_iterator(config={"split": "raw"})

sample, target, tag = odr_iterator[2]


for i in range(0,50):
    sample, target, tag = odr_iterator[i]
    print(target)
    plt.imshow(sample)
    plt.show()
# sample.show()
# Out:
# 2021-11-03 14:43:25,444 - DataHub - DEBUG - starting event
# [b'6_left.jpg' b'[0, 0, 0, 0, 0, 0, 0, 1]']
# [b'6_right.jpg' b'[0, 1, 0, 0, 0, 0, 0, 0]']
# [b'7_left.jpg' b'[0, 0, 0, 0, 0, 0, 0, 1]']
# [b'7_right.jpg' b'[0, 1, 0, 0, 0, 0, 0, 0]']
# [b'11_left.jpg' b'[0, 1, 0, 0, 0, 0, 0, 0]']
# [b'11_right.jpg' b'[0, 1, 0, 0, 0, 0, 0, 0]']
# [b'14_left.jpg' b'[1, 0, 0, 0, 0, 0, 0, 0]']
# [b'14_right.jpg' b'[0, 0, 0, 0, 0, 0, 0, 1]']
# [b'16_left.jpg' b'[1, 0, 0, 0, 0, 0, 0, 0]']
# [b'16_right.jpg' b'[0, 0, 0, 0, 0, 0, 1, 0]']
# [b'17_left.jpg' b'[0, 0, 0, 0, 0, 0, 0, 1]']
# [b'17_right.jpg' b'[0, 0, 0, 0, 0, 0, 0, 1]']
# [b'21_left.jpg' b'[0, 0, 0, 0, 0, 0, 0, 1]']
# [b'21_right.jpg' b'[0, 0, 0, 0, 0, 0, 0, 1]']
# [b'23_left.jpg' b'[0, 0, 0, 0, 0, 1, 0, 0]']
# [b'23_right.jpg' b'[0, 0, 0, 0, 0, 1, 0, 0]']
# [b'25_left.jpg' b'[1, 0, 0, 0, 0, 0, 0, 0]']
# [b'26_left.jpg' b'[0, 1, 0, 0, 0, 0, 0, 0]']
# [b'26_right.jpg' b'[0, 1, 0, 0, 0, 0, 0, 0]']
# [b'27_left.jpg' b'[1, 0, 0, 0, 0, 0, 0, 0]']
# [b'27_right.jpg' b'[0, 0, 0, 0, 0, 0, 0, 1]']
# [b'29_left.jpg' b'[0, 0, 0, 0, 0, 0, 0, 1]']
# [b'29_right.jpg' b'[1, 0, 0, 0, 0, 0, 0, 0]']
# [b'33_left.jpg' b'[1, 0, 0, 0, 0, 0, 0, 0]']
# [b'33_right.jpg' b'[0, 0, 0, 0, 0, 0, 0, 1]']
# [b'35_left.jpg' b'[0, 0, 0, 0, 0, 0, 1, 0]']
# [b'35_right.jpg' b'[1, 0, 0, 0, 0, 0, 0, 0]']
# [b'37_left.jpg' b'[0, 0, 0, 0, 0, 0, 0, 1]']
# [b'37_right.jpg' b'[1, 0, 0, 0, 0, 0, 0, 0]']
# [b'44_left.jpg' b'[0, 1, 0, 0, 0, 0, 0, 0]']
# [b'44_right.jpg' b'[0, 1, 0, 0, 0, 0, 0, 0]']
# [b'45_left.jpg' b'[0, 0, 0, 0, 0, 1, 0, 0]']
# [b'45_right.jpg' b'[0, 0, 0, 0, 0, 1, 0, 0]']
# [b'49_left.jpg' b'[0, 1, 0, 0, 0, 0, 0, 0]']
# [b'49_right.jpg' b'[1, 0, 0, 0, 0, 0, 0, 0]']
# [b'50_right.jpg' b'[0, 1, 0, 0, 0, 0, 0, 0]']
# [b'51_left.jpg' b'[1, 0, 0, 0, 0, 0, 0, 0]']
# [b'51_right.jpg' b'[0, 0, 0, 0, 0, 0, 0, 1]']
# [b'55_left.jpg' b'[0, 0, 0, 0, 1, 0, 0, 0]']
# [b'55_right.jpg' b'[0, 0, 0, 0, 1, 0, 0, 0]']
# [b'64_left.jpg' b'[0, 1, 0, 0, 0, 0, 0, 0]']
# [b'64_right.jpg' b'[0, 0, 0, 0, 0, 0, 0, 1]']
# [b'65_left.jpg' b'[0, 0, 0, 0, 0, 0, 0, 1]']
# [b'65_right.jpg' b'[1, 0, 0, 0, 0, 0, 0, 0]']
# [b'71_left.jpg' b'[0, 1, 0, 0, 0, 0, 0, 0]']
# [b'71_right.jpg' b'[0, 0, 0, 0, 1, 0, 0, 0]']
# [b'72_left.jpg' b'[0, 1, 0, 0, 0, 0, 0, 0]']
# [b'72_right.jpg' b'[0, 0, 0, 0, 0, 0, 0, 1]']
# [b'75_left.jpg' b'[0, 0, 0, 0, 0, 0, 0, 1]']
# [b'75_right.jpg' b'[0, 0, 0, 0, 0, 0, 0, 1]']
